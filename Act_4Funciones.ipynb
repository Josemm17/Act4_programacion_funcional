# %%
import pandas as pd
import os
import funciones as fn

# %% [markdown]
# a) Carga de archivos (csv, xlsx, html y json) a dataframes .

# %%
df=fn.cargar_dataset("Rio.csv")
df
# Out:
#        Unnamed: 0       source                                        name  \
# 0               0  city scrape           Unbelievable Ocean View Apartment
# 1               1  city scrape         EXCELENTE APARTAMENTO EM COPACABANA
# 2               2  city scrape                       Comfort em Copacabana
# 3               3  city scrape            Amazing Huge Apartment in Leblon
# 4               4  city scrape       Lindo quarto sossegado para temporada
# ...           ...          ...                                         ...
# 39494       39494  city scrape         Copa Reformado 1 qrt perto do metrô
# 39495       39495  city scrape                                  Casa Sabiá
# 39496       39496  city scrape  Apartamento na Barata Ribeiro - Copacabana
# 39497       39497  city scrape                      No coração de Ipanema…
# 39498       39498  city scrape                      Aconchego de Copanema!
#
#        host_since                    host_location  host_response_time  \
# 0      2011-11-19           Rio de Janeiro, Brazil  a few days or more
# 1      2013-07-15           Rio de Janeiro, Brazil                 NaN
# 2      2011-11-20           Rio de Janeiro, Brazil      within an hour
# 3      2011-04-25           Rio de Janeiro, Brazil                 NaN
# 4      2011-05-04           Rio de Janeiro, Brazil  within a few hours
# ...           ...                              ...                 ...
# 39494  2014-06-27           Rio de Janeiro, Brazil      within an hour
# 39495  2022-08-24                              NaN                 NaN
# 39496  2020-03-07  State of Rio de Janeiro, Brazil      within an hour
# 39497  2016-04-14  State of Rio de Janeiro, Brazil      within an hour
# 39498  2016-03-08           Rio de Janeiro, Brazil                 NaN
#
#       host_response_rate host_acceptance_rate host_is_superhost  \
# 0                     0%                   0%                 f
# 1                    NaN                  NaN                 f
# 2                   100%                 100%                 t
# 3                    NaN                  NaN                 f
# 4                   100%                  20%                 f
# ...                  ...                  ...               ...
# 39494               100%                  99%               NaN
# 39495                NaN                  NaN                 f
# 39496               100%                 100%                 f
# 39497               100%                 100%                 f
# 39498                NaN                  NaN                 f
#
#       host_neighbourhood  ...  review_scores_checkin  \
# 0                Vidigal  ...                   4.33
# 1                    NaN  ...                   4.97
# 2             Copacabana  ...                   4.94
# 3                 Leblon  ...                    NaN
# 4           Santa Teresa  ...                   5.00
# ...                  ...  ...                    ...
# 39494         Copacabana  ...                    NaN
# 39495           Cachambi  ...                    NaN
# 39496         Copacabana  ...                    NaN
# 39497            Ipanema  ...                    NaN
# 39498         Copacabana  ...                    NaN
#
#        review_scores_communication review_scores_location review_scores_value  \
# 0                             4.67                   4.33                4.00
# 1                             4.97                   4.97                4.86
# 2                             5.00                   4.97                4.94
# 3                              NaN                    NaN                 NaN
# 4                             5.00                   4.60                4.80
# ...                            ...                    ...                 ...
# 39494                          NaN                    NaN                 NaN
# 39495                          NaN                    NaN                 NaN
# 39496                          NaN                    NaN                 NaN
# 39497                          NaN                    NaN                 NaN
# 39498                          NaN                    NaN                 NaN
#
#       instant_bookable calculated_host_listings_count  \
# 0                    f                              1
# 1                    t                              2
# 2                    t                              5
# 3                    f                              1
# 4                    f                              5
# ...                ...                            ...
# 39494                f                             20
# 39495                f                              1
# 39496                t                              1
# 39497                f                              1
# 39498                f                              1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               2
# 2                                               3
# 3                                               1
# 4                                               0
# ...                                           ...
# 39494                                          20
# 39495                                           1
# 39496                                           1
# 39497                                           1
# 39498                                           1
#
#        calculated_host_listings_count_private_rooms  \
# 0                                                 0
# 1                                                 0
# 2                                                 2
# 3                                                 0
# 4                                                 5
# ...                                             ...
# 39494                                             0
# 39495                                             0
# 39496                                             0
# 39497                                             0
# 39498                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                                0               0.05
# 1                                                0               2.31
# 2                                                0               0.25
# 3                                                0                NaN
# 4                                                0               0.04
# ...                                            ...                ...
# 39494                                            0                NaN
# 39495                                            0                NaN
# 39496                                            0                NaN
# 39497                                            0                NaN
# 39498                                            0                NaN
#
# [39499 rows x 51 columns]

# %% [markdown]
# b) Sustitución de valores nulos con el método de “ffill”.

# %%
df_b=fn.sustitución_ffill(df)
df_b
# Out:
# /Users/josemorales/Desktop/Concentracion Freddy/Actividades/funciones.py:39: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   cualitativas = cualitativas_con_nulos.fillna(method="ffill")
#        Unnamed: 0  host_listings_count  host_total_listings_count  \
# 0               0                  1.0                        3.0
# 1               1                  3.0                        3.0
# 2               2                  6.0                        6.0
# 3               3                  1.0                        2.0
# 4               4                  5.0                        6.0
# ...           ...                  ...                        ...
# 39494       39494                 25.0                       27.0
# 39495       39495                  1.0                        1.0
# 39496       39496                  1.0                        1.0
# 39497       39497                  1.0                        1.0
# 39498       39498                  1.0                        1.0
#
#        accommodates  bathrooms  bedrooms  beds  minimum_nights  \
# 0                 4        1.0       2.0   2.0               1
# 1                 4        1.0       1.0   1.0               3
# 2                 2        1.0       1.0   2.0               2
# 3                 6        3.5       3.0   3.0               2
# 4                 1        1.0       1.0   1.0              60
# ...             ...        ...       ...   ...             ...
# 39494             4        2.0       1.0   2.0               1
# 39495             8        1.0       1.0   1.0               1
# 39496             6        1.0       1.0   4.0               2
# 39497             6        1.5       2.0   1.0               2
# 39498             4        1.0       1.0   2.0               3
#
#        maximum_nights  minimum_minimum_nights  ...  host_identity_verified  \
# 0                  90                       1  ...                       t
# 1                  29                       1  ...                       f
# 2                  30                       2  ...                       t
# 3                   7                       2  ...                       f
# 4                 200                      60  ...                       t
# ...               ...                     ...  ...                     ...
# 39494              90                       1  ...                       t
# 39495             365                       1  ...                       t
# 39496             365                       2  ...                       t
# 39497              15                       2  ...                       t
# 39498              14                       3  ...                       f
#
#                 neighbourhood  neighbourhood_cleansed  \
# 0      Rio de Janeiro, Brazil                 Vidigal
# 1      Rio de Janeiro, Brazil              Copacabana
# 2      Rio de Janeiro, Brazil              Copacabana
# 3      Rio de Janeiro, Brazil                  Leblon
# 4      Rio de Janeiro, Brazil            Santa Teresa
# ...                       ...                     ...
# 39494  Rio de Janeiro, Brazil              Copacabana
# 39495  Rio de Janeiro, Brazil             Jacarezinho
# 39496  Rio de Janeiro, Brazil              Copacabana
# 39497  Rio de Janeiro, Brazil                 Ipanema
# 39498  Rio de Janeiro, Brazil              Copacabana
#
#                      property_type        room_type      price  \
# 0               Entire rental unit  Entire home/apt    $236.00
# 1               Entire rental unit  Entire home/apt    $723.00
# 2      Private room in rental unit     Private room  $1,146.00
# 3               Entire rental unit  Entire home/apt  $6,742.00
# 4             Private room in home     Private room     $61.00
# ...                            ...              ...        ...
# 39494           Entire rental unit  Entire home/apt    $957.00
# 39495                  Entire home  Entire home/apt    $288.00
# 39496           Entire rental unit  Entire home/apt    $672.00
# 39497           Entire rental unit  Entire home/apt  $1,083.00
# 39498           Entire rental unit  Entire home/apt  $1,296.00
#
#        has_availability  first_review  last_review  instant_bookable
# 0                     t    2013-02-16   2019-10-05                 f
# 1                     t    2011-12-06   2024-12-14                 t
# 2                     t    2014-07-01   2024-05-06                 t
# 3                     t    2014-07-01   2024-05-06                 f
# 4                     t    2015-03-11   2024-06-22                 f
# ...                 ...           ...          ...               ...
# 39494                 t    2024-12-26   2024-12-27                 f
# 39495                 t    2024-12-26   2024-12-27                 f
# 39496                 t    2024-12-26   2024-12-27                 t
# 39497                 t    2024-12-26   2024-12-27                 f
# 39498                 t    2024-12-26   2024-12-27                 f
#
# [39499 rows x 51 columns]

# %% [markdown]
# c) Sustitución de valores nulos con el método de “bfill”.

# %%
df_c=fn.sustitución_bfill(df)
df_c
# Out:
# /Users/josemorales/Desktop/Concentracion Freddy/Actividades/funciones.py:56: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   cualitativas = cualitativas_con_nulos.fillna(method="bfill")
#        Unnamed: 0  host_listings_count  host_total_listings_count  \
# 0               0                  1.0                        3.0
# 1               1                  3.0                        3.0
# 2               2                  6.0                        6.0
# 3               3                  1.0                        2.0
# 4               4                  5.0                        6.0
# ...           ...                  ...                        ...
# 39494       39494                 25.0                       27.0
# 39495       39495                  1.0                        1.0
# 39496       39496                  1.0                        1.0
# 39497       39497                  1.0                        1.0
# 39498       39498                  1.0                        1.0
#
#        accommodates  bathrooms  bedrooms  beds  minimum_nights  \
# 0                 4        1.0       2.0   2.0               1
# 1                 4        1.0       1.0   1.0               3
# 2                 2        1.0       1.0   2.0               2
# 3                 6        3.5       3.0   3.0               2
# 4                 1        1.0       1.0   1.0              60
# ...             ...        ...       ...   ...             ...
# 39494             4        2.0       1.0   2.0               1
# 39495             8        1.0       1.0   1.0               1
# 39496             6        1.0       1.0   4.0               2
# 39497             6        1.5       2.0   1.0               2
# 39498             4        1.0       1.0   2.0               3
#
#        maximum_nights  minimum_minimum_nights  ...  host_identity_verified  \
# 0                  90                       1  ...                       t
# 1                  29                       1  ...                       f
# 2                  30                       2  ...                       t
# 3                   7                       2  ...                       f
# 4                 200                      60  ...                       t
# ...               ...                     ...  ...                     ...
# 39494              90                       1  ...                       t
# 39495             365                       1  ...                       t
# 39496             365                       2  ...                       t
# 39497              15                       2  ...                       t
# 39498              14                       3  ...                       f
#
#                 neighbourhood  neighbourhood_cleansed  \
# 0      Rio de Janeiro, Brazil                 Vidigal
# 1      Rio de Janeiro, Brazil              Copacabana
# 2      Rio de Janeiro, Brazil              Copacabana
# 3      Rio de Janeiro, Brazil                  Leblon
# 4      Rio de Janeiro, Brazil            Santa Teresa
# ...                       ...                     ...
# 39494  Rio de Janeiro, Brazil              Copacabana
# 39495  Rio de Janeiro, Brazil             Jacarezinho
# 39496  Rio de Janeiro, Brazil              Copacabana
# 39497                     NaN                 Ipanema
# 39498                     NaN              Copacabana
#
#                      property_type        room_type      price  \
# 0               Entire rental unit  Entire home/apt    $236.00
# 1               Entire rental unit  Entire home/apt    $723.00
# 2      Private room in rental unit     Private room  $1,146.00
# 3               Entire rental unit  Entire home/apt  $6,742.00
# 4             Private room in home     Private room     $61.00
# ...                            ...              ...        ...
# 39494           Entire rental unit  Entire home/apt    $957.00
# 39495                  Entire home  Entire home/apt    $288.00
# 39496           Entire rental unit  Entire home/apt    $672.00
# 39497           Entire rental unit  Entire home/apt  $1,083.00
# 39498           Entire rental unit  Entire home/apt  $1,296.00
#
#        has_availability  first_review  last_review  instant_bookable
# 0                     t    2013-02-16   2019-10-05                 f
# 1                     t    2011-12-06   2024-12-14                 t
# 2                     t    2014-07-01   2024-05-06                 t
# 3                     t    2015-03-11   2024-06-22                 f
# 4                     t    2015-03-11   2024-06-22                 f
# ...                 ...           ...          ...               ...
# 39494                 t           NaN          NaN                 f
# 39495                 t           NaN          NaN                 f
# 39496                 t           NaN          NaN                 t
# 39497                 t           NaN          NaN                 f
# 39498                 t           NaN          NaN                 f
#
# [39499 rows x 51 columns]

# %% [markdown]
# d) Sustitución de valores nulos con el método por un “string concreto”

# %%
df_d=fn.sustitución_string(df)
df_d
# Out:
#        Unnamed: 0  host_listings_count  host_total_listings_count  \
# 0               0                  1.0                        3.0
# 1               1                  3.0                        3.0
# 2               2                  6.0                        6.0
# 3               3                  1.0                        2.0
# 4               4                  5.0                        6.0
# ...           ...                  ...                        ...
# 39494       39494                 25.0                       27.0
# 39495       39495                  1.0                        1.0
# 39496       39496                  1.0                        1.0
# 39497       39497                  1.0                        1.0
# 39498       39498                  1.0                        1.0
#
#        accommodates  bathrooms  bedrooms  beds  minimum_nights  \
# 0                 4        1.0       2.0   2.0               1
# 1                 4        1.0       1.0   1.0               3
# 2                 2        1.0       1.0   2.0               2
# 3                 6        3.5       3.0   3.0               2
# 4                 1        1.0       1.0   1.0              60
# ...             ...        ...       ...   ...             ...
# 39494             4        2.0       1.0   2.0               1
# 39495             8        1.0       1.0   1.0               1
# 39496             6        1.0       1.0   4.0               2
# 39497             6        1.5       2.0   1.0               2
# 39498             4        1.0       1.0   2.0               3
#
#        maximum_nights  minimum_minimum_nights  ...  host_identity_verified  \
# 0                  90                       1  ...                       t
# 1                  29                       1  ...                       f
# 2                  30                       2  ...                       t
# 3                   7                       2  ...                       f
# 4                 200                      60  ...                       t
# ...               ...                     ...  ...                     ...
# 39494              90                       1  ...                       t
# 39495             365                       1  ...                       t
# 39496             365                       2  ...                       t
# 39497              15                       2  ...                       t
# 39498              14                       3  ...                       f
#
#                 neighbourhood  neighbourhood_cleansed  \
# 0      Rio de Janeiro, Brazil                 Vidigal
# 1      Rio de Janeiro, Brazil              Copacabana
# 2                Sin registro              Copacabana
# 3                Sin registro                  Leblon
# 4      Rio de Janeiro, Brazil            Santa Teresa
# ...                       ...                     ...
# 39494            Sin registro              Copacabana
# 39495            Sin registro             Jacarezinho
# 39496  Rio de Janeiro, Brazil              Copacabana
# 39497            Sin registro                 Ipanema
# 39498            Sin registro              Copacabana
#
#                      property_type        room_type      price  \
# 0               Entire rental unit  Entire home/apt    $236.00
# 1               Entire rental unit  Entire home/apt    $723.00
# 2      Private room in rental unit     Private room  $1,146.00
# 3               Entire rental unit  Entire home/apt  $6,742.00
# 4             Private room in home     Private room     $61.00
# ...                            ...              ...        ...
# 39494           Entire rental unit  Entire home/apt    $957.00
# 39495                  Entire home  Entire home/apt    $288.00
# 39496           Entire rental unit  Entire home/apt    $672.00
# 39497           Entire rental unit  Entire home/apt  $1,083.00
# 39498           Entire rental unit  Entire home/apt  $1,296.00
#
#        has_availability  first_review   last_review  instant_bookable
# 0                     t    2013-02-16    2019-10-05                 f
# 1                     t    2011-12-06    2024-12-14                 t
# 2                     t    2014-07-01    2024-05-06                 t
# 3                     t  Sin registro  Sin registro                 f
# 4                     t    2015-03-11    2024-06-22                 f
# ...                 ...           ...           ...               ...
# 39494                 t  Sin registro  Sin registro                 f
# 39495                 t  Sin registro  Sin registro                 f
# 39496                 t  Sin registro  Sin registro                 t
# 39497                 t  Sin registro  Sin registro                 f
# 39498                 t  Sin registro  Sin registro                 f
#
# [39499 rows x 51 columns]

# %% [markdown]
# e) Sustitución de valores nulos con el método de “promedio”.

# %%
df_e=fn.sustitución_promedio(df)
df_e
# Out:
#        Unnamed: 0  host_listings_count  host_total_listings_count  \
# 0               0                  1.0                        3.0
# 1               1                  3.0                        3.0
# 2               2                  6.0                        6.0
# 3               3                  1.0                        2.0
# 4               4                  5.0                        6.0
# ...           ...                  ...                        ...
# 39494       39494                 25.0                       27.0
# 39495       39495                  1.0                        1.0
# 39496       39496                  1.0                        1.0
# 39497       39497                  1.0                        1.0
# 39498       39498                  1.0                        1.0
#
#        accommodates  bathrooms  bedrooms  beds  minimum_nights  \
# 0                 4        1.0       2.0   2.0               1
# 1                 4        1.0       1.0   1.0               3
# 2                 2        1.0       1.0   2.0               2
# 3                 6        3.5       3.0   3.0               2
# 4                 1        1.0       1.0   1.0              60
# ...             ...        ...       ...   ...             ...
# 39494             4        2.0       1.0   2.0               1
# 39495             8        1.0       1.0   1.0               1
# 39496             6        1.0       1.0   4.0               2
# 39497             6        1.5       2.0   1.0               2
# 39498             4        1.0       1.0   2.0               3
#
#        maximum_nights  minimum_minimum_nights  ...  host_identity_verified  \
# 0                  90                       1  ...                       t
# 1                  29                       1  ...                       f
# 2                  30                       2  ...                       t
# 3                   7                       2  ...                       f
# 4                 200                      60  ...                       t
# ...               ...                     ...  ...                     ...
# 39494              90                       1  ...                       t
# 39495             365                       1  ...                       t
# 39496             365                       2  ...                       t
# 39497              15                       2  ...                       t
# 39498              14                       3  ...                       f
#
#                 neighbourhood  neighbourhood_cleansed  \
# 0      Rio de Janeiro, Brazil                 Vidigal
# 1      Rio de Janeiro, Brazil              Copacabana
# 2                         NaN              Copacabana
# 3                         NaN                  Leblon
# 4      Rio de Janeiro, Brazil            Santa Teresa
# ...                       ...                     ...
# 39494                     NaN              Copacabana
# 39495                     NaN             Jacarezinho
# 39496  Rio de Janeiro, Brazil              Copacabana
# 39497                     NaN                 Ipanema
# 39498                     NaN              Copacabana
#
#                      property_type        room_type      price  \
# 0               Entire rental unit  Entire home/apt    $236.00
# 1               Entire rental unit  Entire home/apt    $723.00
# 2      Private room in rental unit     Private room  $1,146.00
# 3               Entire rental unit  Entire home/apt  $6,742.00
# 4             Private room in home     Private room     $61.00
# ...                            ...              ...        ...
# 39494           Entire rental unit  Entire home/apt    $957.00
# 39495                  Entire home  Entire home/apt    $288.00
# 39496           Entire rental unit  Entire home/apt    $672.00
# 39497           Entire rental unit  Entire home/apt  $1,083.00
# 39498           Entire rental unit  Entire home/apt  $1,296.00
#
#        has_availability  first_review  last_review  instant_bookable
# 0                     t    2013-02-16   2019-10-05                 f
# 1                     t    2011-12-06   2024-12-14                 t
# 2                     t    2014-07-01   2024-05-06                 t
# 3                     t           NaN          NaN                 f
# 4                     t    2015-03-11   2024-06-22                 f
# ...                 ...           ...          ...               ...
# 39494                 t           NaN          NaN                 f
# 39495                 t           NaN          NaN                 f
# 39496                 t           NaN          NaN                 t
# 39497                 t           NaN          NaN                 f
# 39498                 t           NaN          NaN                 f
#
# [39499 rows x 51 columns]

# %% [markdown]
# f) Sustitución de valores nulos con el método de “mediana”.

# %%
df_f=fn.sustitución_mediana(df)
df_f
# Out:
#        Unnamed: 0  host_listings_count  host_total_listings_count  \
# 0               0                  1.0                        3.0
# 1               1                  3.0                        3.0
# 2               2                  6.0                        6.0
# 3               3                  1.0                        2.0
# 4               4                  5.0                        6.0
# ...           ...                  ...                        ...
# 39494       39494                 25.0                       27.0
# 39495       39495                  1.0                        1.0
# 39496       39496                  1.0                        1.0
# 39497       39497                  1.0                        1.0
# 39498       39498                  1.0                        1.0
#
#        accommodates  bathrooms  bedrooms  beds  minimum_nights  \
# 0                 4        1.0       2.0   2.0               1
# 1                 4        1.0       1.0   1.0               3
# 2                 2        1.0       1.0   2.0               2
# 3                 6        3.5       3.0   3.0               2
# 4                 1        1.0       1.0   1.0              60
# ...             ...        ...       ...   ...             ...
# 39494             4        2.0       1.0   2.0               1
# 39495             8        1.0       1.0   1.0               1
# 39496             6        1.0       1.0   4.0               2
# 39497             6        1.5       2.0   1.0               2
# 39498             4        1.0       1.0   2.0               3
#
#        maximum_nights  minimum_minimum_nights  ...  host_identity_verified  \
# 0                  90                       1  ...                       t
# 1                  29                       1  ...                       f
# 2                  30                       2  ...                       t
# 3                   7                       2  ...                       f
# 4                 200                      60  ...                       t
# ...               ...                     ...  ...                     ...
# 39494              90                       1  ...                       t
# 39495             365                       1  ...                       t
# 39496             365                       2  ...                       t
# 39497              15                       2  ...                       t
# 39498              14                       3  ...                       f
#
#                 neighbourhood  neighbourhood_cleansed  \
# 0      Rio de Janeiro, Brazil                 Vidigal
# 1      Rio de Janeiro, Brazil              Copacabana
# 2                         NaN              Copacabana
# 3                         NaN                  Leblon
# 4      Rio de Janeiro, Brazil            Santa Teresa
# ...                       ...                     ...
# 39494                     NaN              Copacabana
# 39495                     NaN             Jacarezinho
# 39496  Rio de Janeiro, Brazil              Copacabana
# 39497                     NaN                 Ipanema
# 39498                     NaN              Copacabana
#
#                      property_type        room_type      price  \
# 0               Entire rental unit  Entire home/apt    $236.00
# 1               Entire rental unit  Entire home/apt    $723.00
# 2      Private room in rental unit     Private room  $1,146.00
# 3               Entire rental unit  Entire home/apt  $6,742.00
# 4             Private room in home     Private room     $61.00
# ...                            ...              ...        ...
# 39494           Entire rental unit  Entire home/apt    $957.00
# 39495                  Entire home  Entire home/apt    $288.00
# 39496           Entire rental unit  Entire home/apt    $672.00
# 39497           Entire rental unit  Entire home/apt  $1,083.00
# 39498           Entire rental unit  Entire home/apt  $1,296.00
#
#        has_availability  first_review  last_review  instant_bookable
# 0                     t    2013-02-16   2019-10-05                 f
# 1                     t    2011-12-06   2024-12-14                 t
# 2                     t    2014-07-01   2024-05-06                 t
# 3                     t           NaN          NaN                 f
# 4                     t    2015-03-11   2024-06-22                 f
# ...                 ...           ...          ...               ...
# 39494                 t           NaN          NaN                 f
# 39495                 t           NaN          NaN                 f
# 39496                 t           NaN          NaN                 t
# 39497                 t           NaN          NaN                 f
# 39498                 t           NaN          NaN                 f
#
# [39499 rows x 51 columns]

# %% [markdown]
# g) Sustitución de valores nulos con el método de “constante”.

# %%
df_g=fn.sustitución_constante(df)
df_g
# Out:
#        Unnamed: 0  host_listings_count  host_total_listings_count  \
# 0               0                  1.0                        3.0
# 1               1                  3.0                        3.0
# 2               2                  6.0                        6.0
# 3               3                  1.0                        2.0
# 4               4                  5.0                        6.0
# ...           ...                  ...                        ...
# 39494       39494                 25.0                       27.0
# 39495       39495                  1.0                        1.0
# 39496       39496                  1.0                        1.0
# 39497       39497                  1.0                        1.0
# 39498       39498                  1.0                        1.0
#
#        accommodates  bathrooms  bedrooms  beds  minimum_nights  \
# 0                 4        1.0       2.0   2.0               1
# 1                 4        1.0       1.0   1.0               3
# 2                 2        1.0       1.0   2.0               2
# 3                 6        3.5       3.0   3.0               2
# 4                 1        1.0       1.0   1.0              60
# ...             ...        ...       ...   ...             ...
# 39494             4        2.0       1.0   2.0               1
# 39495             8        1.0       1.0   1.0               1
# 39496             6        1.0       1.0   4.0               2
# 39497             6        1.5       2.0   1.0               2
# 39498             4        1.0       1.0   2.0               3
#
#        maximum_nights  minimum_minimum_nights  ...  host_identity_verified  \
# 0                  90                       1  ...                       t
# 1                  29                       1  ...                       f
# 2                  30                       2  ...                       t
# 3                   7                       2  ...                       f
# 4                 200                      60  ...                       t
# ...               ...                     ...  ...                     ...
# 39494              90                       1  ...                       t
# 39495             365                       1  ...                       t
# 39496             365                       2  ...                       t
# 39497              15                       2  ...                       t
# 39498              14                       3  ...                       f
#
#                 neighbourhood  neighbourhood_cleansed  \
# 0      Rio de Janeiro, Brazil                 Vidigal
# 1      Rio de Janeiro, Brazil              Copacabana
# 2                         NaN              Copacabana
# 3                         NaN                  Leblon
# 4      Rio de Janeiro, Brazil            Santa Teresa
# ...                       ...                     ...
# 39494                     NaN              Copacabana
# 39495                     NaN             Jacarezinho
# 39496  Rio de Janeiro, Brazil              Copacabana
# 39497                     NaN                 Ipanema
# 39498                     NaN              Copacabana
#
#                      property_type        room_type      price  \
# 0               Entire rental unit  Entire home/apt    $236.00
# 1               Entire rental unit  Entire home/apt    $723.00
# 2      Private room in rental unit     Private room  $1,146.00
# 3               Entire rental unit  Entire home/apt  $6,742.00
# 4             Private room in home     Private room     $61.00
# ...                            ...              ...        ...
# 39494           Entire rental unit  Entire home/apt    $957.00
# 39495                  Entire home  Entire home/apt    $288.00
# 39496           Entire rental unit  Entire home/apt    $672.00
# 39497           Entire rental unit  Entire home/apt  $1,083.00
# 39498           Entire rental unit  Entire home/apt  $1,296.00
#
#        has_availability  first_review  last_review  instant_bookable
# 0                     t    2013-02-16   2019-10-05                 f
# 1                     t    2011-12-06   2024-12-14                 t
# 2                     t    2014-07-01   2024-05-06                 t
# 3                     t           NaN          NaN                 f
# 4                     t    2015-03-11   2024-06-22                 f
# ...                 ...           ...          ...               ...
# 39494                 t           NaN          NaN                 f
# 39495                 t           NaN          NaN                 f
# 39496                 t           NaN          NaN                 t
# 39497                 t           NaN          NaN                 f
# 39498                 t           NaN          NaN                 f
#
# [39499 rows x 51 columns]

# %% [markdown]
# i) Identificación de valores nulos por columna y por dataframe”.

# %%
fn.cuenta_valores_nulos(df)
# Out:
# ('Valores nulos por columna:',
#  Unnamed: 0                                          0
#  source                                              0
#  name                                                0
#  host_since                                          2
#  host_location                                    7646
#  host_response_time                               3921
#  host_response_rate                               3921
#  host_acceptance_rate                             3534
#  host_is_superhost                                1170
#  host_neighbourhood                               5535
#  host_listings_count                                 2
#  host_total_listings_count                           2
#  host_identity_verified                              2
#  neighbourhood                                   22619
#  neighbourhood_cleansed                              0
#  property_type                                       0
#  room_type                                           0
#  accommodates                                        0
#  bathrooms                                        2890
#  bedrooms                                          523
#  beds                                             2869
#  price                                            2855
#  minimum_nights                                      0
#  maximum_nights                                      0
#  minimum_minimum_nights                              0
#  maximum_minimum_nights                              0
#  minimum_maximum_nights                              0
#  maximum_maximum_nights                              0
#  has_availability                                  497
#  availability_30                                     0
#  availability_60                                     0
#  availability_90                                     0
#  availability_365                                    0
#  number_of_reviews                                   0
#  number_of_reviews_ltm                               0
#  number_of_reviews_l30d                              0
#  first_review                                    10419
#  last_review                                     10419
#  review_scores_rating                            10419
#  review_scores_accuracy                          10420
#  review_scores_cleanliness                       10419
#  review_scores_checkin                           10420
#  review_scores_communication                     10420
#  review_scores_location                          10421
#  review_scores_value                             10420
#  instant_bookable                                    0
#  calculated_host_listings_count                      0
#  calculated_host_listings_count_entire_homes         0
#  calculated_host_listings_count_private_rooms        0
#  calculated_host_listings_count_shared_rooms         0
#  reviews_per_month                               10419
#  dtype: int64,
#  'Valores nulos por dataframe: ',
#  162184)
